# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','california','dc','california','texas','texas'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3]
})

# %%
# plot num_children vs num_pets
# show the number of records
# save the plot to a PNG
plt.plot(kind='scatter',x='num_children',y='num_pets',color='red')
# len(df)
# plt.savefig('output.png')
# Out:
# []

# %%
plt.xlabel('My Kids')
plt.ylabel('Your Pets')
plt.title('Chaos Example')

plt.plot('num_children','num_pets', markersize='20', color='#5739f9',marker='o', markeredgecolor='red', data=df)
# plt.plot(data=df, x='num_children', y='num_pets')
# plt.plot("num_children", "num_pets", data=df)
